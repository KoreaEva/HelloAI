# %%
# !pip install azure-storage-file
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 47 kB 2.7 MB/s
# ...
#      |████████████████████████████████| 4.1 MB 11.6 MB/s
# ...

# %%
from azure.storage.file import FileService
file_service = FileService(account_name='helloaistorage', account_key='hIwnbOZwAPX/tR1HKQ12RE33Al65IKPQXjlO2V+NfMJ/zl42lBFZzTwZ5Uj6jmyVLcdwqTbexVoH+ASt7fRfKQ==')

# %%
file_service.create_share('myshare')
# Out:
# True

# %%
file_service.create_directory('myshare', 'sampledir')
# Out:
# True

# %%
from azure.storage.file import ContentSettings
file_service.create_file_from_path(
    'myshare',
    None,  # We want to create this file in the root directory, so we specify None for the directory_name
    'myfile',
    'IU.jpg',
    content_settings=ContentSettings(content_type='image/png'))

# %%
generator = file_service.list_directories_and_files('myshare')
for file_or_dir in generator:
    print(file_or_dir.name)
# Out:
# myfile
# sampledir

# %%
file_service.get_file_to_path('myshare', None, 'myfile', 'out-IU.jpg')

# %%
metadata = {"foo": "bar"}
snapshot = file_service.snapshot_share('myshare', metadata=metadata)

# %%
shares = list(file_service.list_shares(include_snapshots=True))

# %%
directories_and_files = list(
    file_service.list_directories_and_files('myshare', snapshot='2022-11-06T13:56:09.0000000Z'))

# %%
directories_and_files
for file_or_dir in generator:
    print(file_or_dir.name)
# Out:
# myfile
# sampledir

# %%
file_service.delete_share('myshare', snapshot='2022-11-06T13:56:09.0000000Z')
# Out:
# True

# %%
file_service.delete_file('myshare', None, 'myfile')

# %%
file_service.delete_share('myshare')
# Out:
# True
